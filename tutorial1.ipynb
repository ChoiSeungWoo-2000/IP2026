# %%
tu = (23, 'abc', 4.56, (2,3), 'def')

# %%
print(tu)
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
li = ["abc", 34, 4.34, 23]

# %%
print(li)
# Out:
# ['abc', 34, 4.34, 23]

# %%
st = "Hello World"

# %%
print(st)
# Out:
# Hello World

# %%
st = 'Hello World'

# %%
print(st)
# Out:
# Hello World

# %%
st = """This is a multi-line
string that uses triple quotes."""

# %%
print(st)
# Out:
# This is a multi-line
# string that uses triple quotes.

# %%
tu = (23, 'abc', 4.56, (2,3), 'def') # tuple 다양한 자료형 입력가능

# %%
tu[1]
# Out:
# 'abc'

# %%
li = ["abc", 34, 4.34, 23] #list

# %%
li[1]
# Out:
# 34

# %%
st = "Hello World" #string

# %%
st[1]
# Out:
# 'e'

# %%
tu[1] = 45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 tu[1] = 45
#
# TypeError: 'tuple' object does not support item assignment

# %%
li[1] = 45

# %%
li #list 는 값 바꾸기 가능 tuple 안댐
# Out:
# ['abc', 45, 4.34, 23]

# %%
li[-1]
# Out:
# 23

# %%
li[1:3]
# Out:
# [45, 4.34]

# %%
li[:3]
# Out:
# ['abc', 45, 4.34]

# %%
li[:3:2] #2개씩 증가
# Out:
# ['abc', 4.34]

# %%
t = (23, 'abc', 4.56, (2,3), 'def')

# %%
t[1]
# Out:
# 'abc'

# %%
t[-3]
# Out:
# 4.56

# %%
t = (23, 'abc', 4.56, (2,3), 'def')

# %%
t[1:4]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1:2]
# Out:
# ('abc', (2, 3))

# %%
t = (23, 'abc', 4.56, (2,3), 'def')

# %%
t[:2]
# Out:
# (23, 'abc')

# %%
t[2:]
# Out:
# (4.56, (2, 3), 'def')

# %%
t[:]
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
list1 = [1, 2, 3]

# %%
list2 = list1

# %%
list2
# Out:
# [1, 2, 3]

# %%
list2[1] = 99

# %%
list2
# Out:
# [1, 99, 3]

# %%
list1 #list1도 바뀌어져있음. 주소에있는값을 바꾼거라 같이 바뀜. soft copy list2만 바뀌게 할려면 hard copy
# Out:
# [1, 99, 3]

# %%
list1 = [1, 2, 3]

# %%
list2 = list1[:]

# %%
list2[1] = 99

# %%
list1
# Out:
# [1, 2, 3]

# %%
list2 #list2 만 바뀜.
# Out:
# [1, 99, 3]

# %%
t = [1, 2, 4, 5]

# %%
3 in t # 3이 t에 있냐?
# Out:
# False

# %%
4 in t
# Out:
# True

# %%
4 not in t
# Out:
# False

# %%
a = 'abcde'

# %%
'c' in a
# Out:
# True

# %%
'cd' in a
# Out:
# True

# %%
'ac' in a
# Out:
# False

# %%
(1, 2, 3) + (4, 5, 6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
[1, 2, 3] + [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
"Hello" + " " + "World"
# Out:
# 'Hello World'
